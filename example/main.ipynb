# %%
from shapfs import *

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
fs=feature_selection(type=1)

# %%
data=pd.read_csv("/Users/hjy/Desktop/corr_data.csv")

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
fs.fit(x,y,0.8)
# Out:
# Preprocessing data...
# Model training...
# Computing explanations...
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# Features selecting...
# ['Crosses', 'Shots_on_target', 'Aerial_success', 'Long_balls', 'Match_location', 'Fouls']

# %%
x.columns
# Out:
# Index(['Team_quality', 'Opponent_quality', 'Match_location', 'Match_outcome',
#        'Shots_on_target', 'SFCA', 'Short_passes', 'Long_balls', 'Crosses',
#        'Aerial_success', 'Offsides', 'Tackles', 'Fouls', 'Yellow_cards'],
#       dtype='object')

# %%
fs.result
# Out:
# ['Crosses',
#  'Shots_on_target',
#  'Aerial_success',
#  'Long_balls',
#  'Match_location',
#  'Fouls']

# %%
fs.feature_ranking
# Out:
#         Shapely     Features name
# 0   1899.489380           Crosses
# 1   1286.751465   Shots_on_target
# 2    432.973755    Aerial_success
# 3    339.032471        Long_balls
# 4    292.399658    Match_location
# 5    264.869751             Fouls
# 6    202.000931      Short_passes
# 7    166.699936          Offsides
# 8    154.393250      Yellow_cards
# 9    145.493393           Tackles
# 10   115.539291  Opponent_quality
# 11    53.985657              SFCA
# 12    41.924843     Match_outcome
# 13    34.386425      Team_quality

# %%
fs.feature_importance_plot()

# %%
fs.feature_beeswarm()
